# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
x= np.random.randint(10, 60, (10))
no=[49,45, 54,16, 31, 56,12, 28, 33,18,48, 54,21,53, 43, 30, 23 , 48 , 33 , 54 , 47, 22, 34, 59,
55, 44, 54,35, 18, 24, 37, 58, 16, 36, 29, 43, 49, 35 , 55, 34, 45, 55, 49, 48, 14, 18, 16, 58,
52 , 25]
l= [10,20, 30,40,50,60]
plt.hist (no, color="b", edgecolor="r", rwidth=0.9)
plt.title("wscube")
plt. xlabel ("python")
plt. ylabel ("No.")
plt. show( )
