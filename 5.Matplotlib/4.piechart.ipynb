# %%
import matplotlib.pyplot as plt

# %%
languages= ["C++", "Java", "Web", "python"]
x= [50,40,20,30]
ex=[0.0,0.0,0.0,0.1]
c=["b","g","m","y"]

# %%
plt.pie(x, labels=languages, colors=c, explode=ex, autopct="%0.2f%%")
plt.show()
