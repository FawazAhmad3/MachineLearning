# %%
import matplotlib.pyplot as plt

# %%
x= ["python", "c++", "c", "java"]
y= [85,70,60,82]

# %%
plt. xlabel("Language", fontsize=15)
plt. ylabel("No.", fontsize=15)

plt. title("wscube", fontsize=15)
c= ["y", "c", "m" , "g"]
plt. bar(x,y,width=0.4, color=c, edgecolor="r",linewidth=1)
plt. show( )
